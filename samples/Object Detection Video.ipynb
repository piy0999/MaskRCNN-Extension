# %% [markdown]
# # Mask R-CNN Demo
#
# A quick intro to using the pre-trained model to detect and segment objects.

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
import random
import itertools
import colorsys
from PIL import Image, ImageDraw, ImageFont
import matplotlib.font_manager as fm
from pytube import YouTube
import glob
# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")

# %% [markdown]
# ## Configurations
#
# We'll be using a model trained on the MS-COCO dataset. The configurations of this model are in the ```CocoConfig``` class in ```coco.py```.
#
# For inferencing, modify the configurations a bit to fit the task. To do so, sub-class the ```CocoConfig``` class and override the attributes you need to change.

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Create Model and Load Trained Weights

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)

# %% [markdown]
# ## Class Names
#
# The model classifies objects and returns class IDs, which are integer value that identify each class. Some datasets assign integer values to their classes and some don't. For example, in the MS-COCO dataset, the 'person' class is 1 and 'teddy bear' is 88. The IDs are often sequential, but not always. The COCO dataset, for example, has classes associated with class IDs 70 and 72, but not 71.
#
# To improve consistency, and to support training on data from multiple sources at the same time, our ```Dataset``` class assigns it's own sequential integer IDs to each class. For example, if you load the COCO dataset using our ```Dataset``` class, the 'person' class would get class ID = 1 (just like COCO) and the 'teddy bear' class is 78 (different from COCO). Keep that in mind when mapping class IDs to class names.
#
# To get the list of class names, you'd load the dataset and then use the ```class_names``` property like this.
# ```
# # Load COCO dataset
# dataset = coco.CocoDataset()
# dataset.load_coco(COCO_DIR, "train")
# dataset.prepare()
#
# # Print class names
# print(dataset.class_names)
# ```
#
# We don't want to require you to download the COCO dataset just to run this demo, so we're including the list of class names below. The index of the class name in the list represent its ID (first class is 0, second is 1, third is 2, ...etc.)

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %%
def apply_mask(image, mask, color, alpha=0.5):
    """Apply the given mask to the image.
    """
    for c in range(3):
        image[:, :, c] = np.where(mask == 1,
                                  image[:, :, c] *
                                  (1 - alpha) + alpha * color[c] * 255,
                                  image[:, :, c])
    return image

# %%
def random_colors(N, bright=True):
    """
    Generate random colors.
    To get visually distinct colors, generate them in HSV space then
    convert to RGB.
    """
    brightness = 1.0 if bright else 0.7
    hsv = [(i / N, 1, brightness) for i in range(N)]
    colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
    random.shuffle(colors)
    return colors

# %%
def save_image(image, image_name, boxes, masks, class_ids, scores, class_names, filter_classs_names=None,
               scores_thresh=0.1, save_dir=None, mode=0):
    """
        image: image array
        image_name: image name
        boxes: [num_instance, (y1, x1, y2, x2, class_id)] in image coordinates.
        masks: [num_instances, height, width]
        class_ids: [num_instances]
        scores: confidence scores for each box
        class_names: list of class names of the dataset
        filter_classs_names: (optional) list of class names we want to draw
        scores_thresh: (optional) threshold of confidence scores
        save_dir: (optional) the path to store image
        mode: (optional) select the result which you want
                mode = 0 , save image with bbox,class_name,score and mask;
                mode = 1 , save image with bbox,class_name and score;
                mode = 2 , save image with class_name,score and mask;
                mode = 3 , save mask with black background;
    """
    mode_list = [0, 1, 2, 3]
    assert mode in mode_list, "mode's value should in mode_list %s" % str(mode_list)

    if save_dir is None:
        save_dir = os.path.join(os.getcwd(), "output")
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)

    useful_mask_indices = []

    N = boxes.shape[0]
    if not N:
        print("\n*** No instances in image %s to draw *** \n" % (image_name))
        return
    else:
        assert boxes.shape[0] == masks.shape[-1] == class_ids.shape[0]

    for i in range(N):
        # filter
        class_id = class_ids[i]
        score = scores[i] if scores is not None else None
        if score is None or score < scores_thresh:
            continue

        label = class_names[class_id]
        if (filter_classs_names is not None) and (label not in filter_classs_names):
            continue

        if not np.any(boxes[i]):
            # Skip this instance. Has no bbox. Likely lost in image cropping.
            continue

        useful_mask_indices.append(i)

    if len(useful_mask_indices) == 0:
        print("\n*** No instances in image %s to draw *** \n" % (image_name))
        return

    colors = random_colors(len(useful_mask_indices))

    if mode != 3:
        masked_image = image.astype(np.uint8).copy()
    else:
        masked_image = np.zeros(image.shape).astype(np.uint8)

    if mode != 1:
        for index, value in enumerate(useful_mask_indices):
            masked_image = apply_mask(masked_image, masks[:, :, value], colors[index])

    masked_image = Image.fromarray(masked_image)

    if mode == 3:
        masked_image.save(os.path.join(save_dir, '%s.jpg' % (image_name)))
        return

    draw = ImageDraw.Draw(masked_image)
    colors = np.array(colors).astype(int) * 255

    for index, value in enumerate(useful_mask_indices):
        class_id = class_ids[value]
        score = scores[value]
        label = class_names[class_id]

        y1, x1, y2, x2 = boxes[value]
        if mode != 2:
            color = tuple(colors[index])
            draw.rectangle((x1, y1, x2, y2), outline=color)

        # Label
        font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf", 15)
        draw.text((x1, y1), "%s %f" % (label, score), (0, 0, 0), font)
        #draw.text((x1, y1), "%s %f" % (label, score), (255, 255, 255))

    masked_image.save(os.path.join(save_dir, '%s.jpg' % (image_name)))

# %% [markdown]
# ## Run Object Detection

# %%
YouTube('https://www.youtube.com/watch?v=_c1XNARpi0I').streams.first().download(filename='video')
# Out:
# '/userhome/comp3314/c3314g15/MaskRCNN-Extension/samples/video.mp4'

# %%
# !ffmpeg -i video.mp4 -vf fps=30 img/output%04d.jpg
# Out:
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'video.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2019-03-30T12:22:46.000000Z
#   Duration: 00:02:03.04, start: 0.000000, bitrate: 356 kb/s
#     Stream #0:0(und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709), 1280x720 [SAR 1:1 DAR 16:9], 256 kb/s, 29.97 fps, 29.97 tbr, 30k tbn, 59.94 tbc (default)
#     Metadata:
#       creation_time   : 2019-03-30T12:22:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/30/2019.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 96 kb/s (default)
#     Metadata:
#       creation_time   : 2019-03-30T12:22:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/30/2019.
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> mjpeg (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x5579431a9380] deprecated pixel format used, make sure you did set range correctly
# Output #0, image2, to 'img/output%04d.jpg':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: mjpeg, yuvj420p(pc), 1280x720 [SAR 1:1 DAR 16:9], q=2-31, 200 kb/s, 30 fps, 30 tbn, 30 tbc (default)
#     Metadata:
#       creation_time   : 2019-03-30T12:22:46.000000Z
#       handler_name    : ISO Media file produced by Google Inc. Created on: 03/30/2019.
#       encoder         : Lavc57.107.100 mjpeg
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/200000 buffer size: 0 vbv_delay: -1
# frame= 3691 fps= 78 q=24.8 Lsize=N/A time=00:02:03.03 bitrate=N/A speed=2.58x
# video:103755kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %%
count = 0
for filename in glob.glob('img/*.jpg'): #assuming gif
    image = skimage.io.imread(filename)
    results = model.detect([image], verbose=0)
    r = results[0]
    count += 1
    image_name = 'image_'+str(count).zfill(4)
    save_image(image, image_name, r['rois'], r['masks'],r['class_ids'],r['scores'],class_names,save_dir='output',mode=0)
# Out:
# *** No instances in image image_0003 to draw ***
#
#
# *** No instances in image image_0007 to draw ***
#
#
# *** No instances in image image_0017 to draw ***
#
#
# *** No instances in image image_0054 to draw ***
#
#
# *** No instances in image image_0083 to draw ***
#
#
# *** No instances in image image_0093 to draw ***
#
#
# *** No instances in image image_0101 to draw ***
#
#
# *** No instances in image image_0107 to draw ***
#
#
# *** No instances in image image_0132 to draw ***
#
#
# *** No instances in image image_0134 to draw ***
#
#
# *** No instances in image image_0153 to draw ***
#
#
# *** No instances in image image_0155 to draw ***
#
#
# *** No instances in image image_0160 to draw ***
#
#
# *** No instances in image image_0167 to draw ***
#
#
# *** No instances in image image_0168 to draw ***
#
#
# *** No instances in image image_0182 to draw ***
#
#
# *** No instances in image image_0194 to draw ***
#
#
# *** No instances in image image_0195 to draw ***
#
#
# *** No instances in image image_0200 to draw ***
#
#
# *** No instances in image image_0221 to draw ***
#
#
# *** No instances in image image_0225 to draw ***
#
#
# *** No instances in image image_0238 to draw ***
#
#
# *** No instances in image image_0252 to draw ***
#
#
# *** No instances in image image_0260 to draw ***
#
#
# *** No instances in image image_0276 to draw ***
#
#
# *** No instances in image image_0286 to draw ***
#
#
# *** No instances in image image_0288 to draw ***
#
#
# *** No instances in image image_0302 to draw ***
#
#
# *** No instances in image image_0306 to draw ***
#
#
# *** No instances in image image_0317 to draw ***
#
#
# *** No instances in image image_0319 to draw ***
#
#
# *** No instances in image image_0330 to draw ***
#
#
# *** No instances in image image_0333 to draw ***
#
#
# *** No instances in image image_0348 to draw ***
#
#
# *** No instances in image image_0350 to draw ***
#
#
# *** No instances in image image_0370 to draw ***
#
#
# *** No instances in image image_0386 to draw ***
#
#
# *** No instances in image image_0392 to draw ***
#
#
# *** No instances in image image_0393 to draw ***
#
#
# *** No instances in image image_0401 to draw ***
#
#
# *** No instances in image image_0405 to draw ***
#
#
# *** No instances in image image_0411 to draw ***
#
#
# *** No instances in image image_0413 to draw ***
#
#
# *** No instances in image image_0420 to draw ***
#
#
# *** No instances in image image_0421 to draw ***
#
#
# *** No instances in image image_0432 to draw ***
#
#
# *** No instances in image image_0455 to draw ***
#
#
# *** No instances in image image_0464 to draw ***
#
#
# *** No instances in image image_0466 to draw ***
#
#
# *** No instances in image image_0476 to draw ***
#
#
# *** No instances in image image_0485 to draw ***
#
#
# *** No instances in image image_0486 to draw ***
#
#
# *** No instances in image image_0492 to draw ***
#
#
# *** No instances in image image_0497 to draw ***
#
#
# *** No instances in image image_0498 to draw ***
#
#
# *** No instances in image image_0507 to draw ***
#
#
# *** No instances in image image_0536 to draw ***
#
#
# *** No instances in image image_0549 to draw ***
#
#
# *** No instances in image image_0557 to draw ***
#
#
# *** No instances in image image_0565 to draw ***
#
#
# *** No instances in image image_0569 to draw ***
#
#
# *** No instances in image image_0570 to draw ***
#
#
# *** No instances in image image_0578 to draw ***
#
#
# *** No instances in image image_0580 to draw ***
#
#
# *** No instances in image image_0588 to draw ***
#
#
# *** No instances in image image_0599 to draw ***
#
#
# *** No instances in image image_0608 to draw ***
#
#
# *** No instances in image image_0611 to draw ***
#
#
# *** No instances in image image_0621 to draw ***
#
#
# *** No instances in image image_0625 to draw ***
#
#
# *** No instances in image image_0631 to draw ***
#
#
# *** No instances in image image_0641 to draw ***
#
#
# *** No instances in image image_0652 to draw ***
#
#
# *** No instances in image image_0654 to draw ***
#
#
# *** No instances in image image_0661 to draw ***
#
#
# *** No instances in image image_0662 to draw ***
#
#
# *** No instances in image image_0665 to draw ***
#
#
# *** No instances in image image_0667 to draw ***
#
#
# *** No instances in image image_0678 to draw ***
#
#
# *** No instances in image image_0689 to draw ***
#
#
# *** No instances in image image_0696 to draw ***
#
#
# *** No instances in image image_0702 to draw ***
#
#
# *** No instances in image image_0707 to draw ***
#
#
# *** No instances in image image_0723 to draw ***
#
#
# *** No instances in image image_0732 to draw ***
#
#
# *** No instances in image image_0740 to draw ***
#
#
# *** No instances in image image_0743 to draw ***
#
#
# *** No instances in image image_0760 to draw ***
#
#
# *** No instances in image image_0772 to draw ***
#
#
# *** No instances in image image_0775 to draw ***
#
#
# *** No instances in image image_0787 to draw ***
#
#
# *** No instances in image image_0790 to draw ***
#
#
# *** No instances in image image_0794 to draw ***
#
#
# *** No instances in image image_0795 to draw ***
#
#
# *** No instances in image image_0809 to draw ***
#
#
# *** No instances in image image_0813 to draw ***
#
#
# *** No instances in image image_0815 to draw ***
#
#
# *** No instances in image image_0846 to draw ***
#
#
# *** No instances in image image_0854 to draw ***
#
#
# *** No instances in image image_0857 to draw ***
#
#
# *** No instances in image image_0874 to draw ***
#
#
# *** No instances in image image_0884 to draw ***
#
#
# *** No instances in image image_0887 to draw ***
#
#
# *** No instances in image image_0904 to draw ***
#
#
# *** No instances in image image_0929 to draw ***
#
#
# *** No instances in image image_0941 to draw ***
#
#
# *** No instances in image image_0942 to draw ***
#
#
# *** No instances in image image_0946 to draw ***
#
#
# *** No instances in image image_0977 to draw ***
#
#
# *** No instances in image image_0981 to draw ***
#
#
# *** No instances in image image_1015 to draw ***
#
#
# *** No instances in image image_1025 to draw ***
#
#
# *** No instances in image image_1026 to draw ***
#
#
# *** No instances in image image_1027 to draw ***
#
#
# *** No instances in image image_1036 to draw ***
#
#
# *** No instances in image image_1045 to draw ***
#
#
# *** No instances in image image_1054 to draw ***
#
#
# *** No instances in image image_1058 to draw ***
#
#
# *** No instances in image image_1059 to draw ***
#
#
# *** No instances in image image_1071 to draw ***
#
#
# *** No instances in image image_1080 to draw ***
#
#
# *** No instances in image image_1089 to draw ***
#
#
# *** No instances in image image_1092 to draw ***
#
#
# *** No instances in image image_1095 to draw ***
#
#
# *** No instances in image image_1098 to draw ***
#
#
# *** No instances in image image_1120 to draw ***
#
#
# *** No instances in image image_1124 to draw ***
#
#
# *** No instances in image image_1134 to draw ***
#
#
# *** No instances in image image_1145 to draw ***
#
#
# *** No instances in image image_1147 to draw ***
#
#
# *** No instances in image image_1148 to draw ***
#
#
# *** No instances in image image_1168 to draw ***
#
#
# *** No instances in image image_1172 to draw ***
#
#
# *** No instances in image image_1174 to draw ***
#
#
# *** No instances in image image_1176 to draw ***
#
#
# *** No instances in image image_1201 to draw ***
#
#
# *** No instances in image image_1213 to draw ***
#
#
# *** No instances in image image_1230 to draw ***
#
#
# *** No instances in image image_1240 to draw ***
#
#
# *** No instances in image image_1255 to draw ***
#
#
# *** No instances in image image_1259 to draw ***
#
#
# *** No instances in image image_1260 to draw ***
#
#
# *** No instances in image image_1264 to draw ***
#
#
# *** No instances in image image_1266 to draw ***
#
#
# *** No instances in image image_1272 to draw ***
#
#
# *** No instances in image image_1301 to draw ***
#
#
# *** No instances in image image_1315 to draw ***
#
#
# *** No instances in image image_1323 to draw ***
#
#
# *** No instances in image image_1327 to draw ***
#
#
# *** No instances in image image_1346 to draw ***
#
#
# *** No instances in image image_1388 to draw ***
#
#
# *** No instances in image image_1395 to draw ***
#
#
# *** No instances in image image_1411 to draw ***
#
#
# *** No instances in image image_1414 to draw ***
#
#
# *** No instances in image image_1423 to draw ***
#
#
# *** No instances in image image_1437 to draw ***
#
#
# *** No instances in image image_1442 to draw ***
#
#
# *** No instances in image image_1448 to draw ***
# *** No instances in image image_1467 to draw ***
#
#
# *** No instances in image image_1476 to draw ***
#
#
# *** No instances in image image_1485 to draw ***
#
#
# *** No instances in image image_1494 to draw ***
#
#
# *** No instances in image image_1504 to draw ***
#
#
# *** No instances in image image_1517 to draw ***
#
#
# *** No instances in image image_1527 to draw ***
#
#
# *** No instances in image image_1535 to draw ***
#
#
# *** No instances in image image_1540 to draw ***
#
#
# *** No instances in image image_1546 to draw ***
#
#
# *** No instances in image image_1548 to draw ***
#
#
# *** No instances in image image_1557 to draw ***
#
#
# *** No instances in image image_1570 to draw ***
#
#
# *** No instances in image image_1580 to draw ***
#
#
# *** No instances in image image_1587 to draw ***
#
#
# *** No instances in image image_1594 to draw ***
#
#
# *** No instances in image image_1603 to draw ***
#
#
# *** No instances in image image_1613 to draw ***
#
#
# *** No instances in image image_1627 to draw ***
#
#
# *** No instances in image image_1634 to draw ***
#
#
# *** No instances in image image_1644 to draw ***
#
#
# *** No instances in image image_1646 to draw ***
#
#
# *** No instances in image image_1650 to draw ***
#
#
# *** No instances in image image_1655 to draw ***
#
#
# *** No instances in image image_1656 to draw ***
#
#
# *** No instances in image image_1659 to draw ***
#
#
# *** No instances in image image_1668 to draw ***
#
#
# *** No instances in image image_1670 to draw ***
#
#
# *** No instances in image image_1688 to draw ***
#
#
# *** No instances in image image_1689 to draw ***
#
#
# *** No instances in image image_1691 to draw ***
#
#
# *** No instances in image image_1701 to draw ***
#
#
# *** No instances in image image_1713 to draw ***
#
#
# *** No instances in image image_1717 to draw ***
#
#
# *** No instances in image image_1722 to draw ***
#
#
# *** No instances in image image_1734 to draw ***
#
#
# *** No instances in image image_1738 to draw ***
#
#
# *** No instances in image image_1739 to draw ***
#
#
# *** No instances in image image_1773 to draw ***
#
#
# *** No instances in image image_1786 to draw ***
#
#
# *** No instances in image image_1787 to draw ***
#
#
# *** No instances in image image_1802 to draw ***
#
#
# *** No instances in image image_1814 to draw ***
#
#
# *** No instances in image image_1815 to draw ***
#
#
# *** No instances in image image_1824 to draw ***
#
#
# *** No instances in image image_1831 to draw ***
#
#
# *** No instances in image image_1837 to draw ***
#
#
# *** No instances in image image_1841 to draw ***
#
#
# *** No instances in image image_1877 to draw ***
#
#
# *** No instances in image image_1889 to draw ***
#
#
# *** No instances in image image_1893 to draw ***
#
#
# *** No instances in image image_1902 to draw ***
#
#
# *** No instances in image image_1904 to draw ***
#
#
# *** No instances in image image_1905 to draw ***
#
#
# *** No instances in image image_1906 to draw ***
#
#
# *** No instances in image image_1913 to draw ***
#
#
# *** No instances in image image_1919 to draw ***
#
#
# *** No instances in image image_1928 to draw ***
#
#
# *** No instances in image image_1931 to draw ***
#
#
# *** No instances in image image_1935 to draw ***
#
#
# *** No instances in image image_1964 to draw ***
#
#
# *** No instances in image image_1967 to draw ***
#
#
# *** No instances in image image_1978 to draw ***
#
#
# *** No instances in image image_1982 to draw ***
#
#
# *** No instances in image image_1986 to draw ***
#
#
# *** No instances in image image_1991 to draw ***
#
#
# *** No instances in image image_2002 to draw ***
#
#
# *** No instances in image image_2007 to draw ***
#
#
# *** No instances in image image_2017 to draw ***
#
#
# *** No instances in image image_2033 to draw ***
#
#
# *** No instances in image image_2034 to draw ***
#
#
# *** No instances in image image_2056 to draw ***
#
#
# *** No instances in image image_2060 to draw ***
#
#
# *** No instances in image image_2061 to draw ***
#
#
# *** No instances in image image_2067 to draw ***
#
#
# *** No instances in image image_2071 to draw ***
#
#
# *** No instances in image image_2073 to draw ***
#
#
# *** No instances in image image_2087 to draw ***
#
#
# *** No instances in image image_2089 to draw ***
#
#
# *** No instances in image image_2101 to draw ***
#
#
# *** No instances in image image_2109 to draw ***
#
#
# *** No instances in image image_2126 to draw ***
#
#
# *** No instances in image image_2132 to draw ***
#
#
# *** No instances in image image_2133 to draw ***
#
#
# *** No instances in image image_2137 to draw ***
#
#
# *** No instances in image image_2144 to draw ***
#
#
# *** No instances in image image_2152 to draw ***
#
#
# *** No instances in image image_2159 to draw ***
#
#
# *** No instances in image image_2165 to draw ***
#
#
# *** No instances in image image_2174 to draw ***
#
#
# *** No instances in image image_2176 to draw ***
#
#
# *** No instances in image image_2178 to draw ***
#
#
# *** No instances in image image_2187 to draw ***
#
#
# *** No instances in image image_2203 to draw ***
#
#
# *** No instances in image image_2207 to draw ***
#
#
# *** No instances in image image_2213 to draw ***
#
#
# *** No instances in image image_2217 to draw ***
#
#
# *** No instances in image image_2218 to draw ***
#
#
# *** No instances in image image_2230 to draw ***
#
#
# *** No instances in image image_2232 to draw ***
#
#
# *** No instances in image image_2236 to draw ***
#
#
# *** No instances in image image_2240 to draw ***
#
#
# *** No instances in image image_2260 to draw ***
#
#
# *** No instances in image image_2266 to draw ***
#
#
# *** No instances in image image_2291 to draw ***
#
#
# *** No instances in image image_2300 to draw ***
#
#
# *** No instances in image image_2301 to draw ***
#
#
# *** No instances in image image_2323 to draw ***
#
#
# *** No instances in image image_2338 to draw ***
#
#
# *** No instances in image image_2344 to draw ***
#
#
# *** No instances in image image_2345 to draw ***
#
#
# *** No instances in image image_2356 to draw ***
#
#
# *** No instances in image image_2366 to draw ***
#
#
# *** No instances in image image_2374 to draw ***
#
#
# *** No instances in image image_2375 to draw ***
#
#
# *** No instances in image image_2376 to draw ***
#
#
# *** No instances in image image_2393 to draw ***
#
#
# *** No instances in image image_2419 to draw ***
#
#
# *** No instances in image image_2422 to draw ***
#
#
# *** No instances in image image_2435 to draw ***
#
#
# *** No instances in image image_2449 to draw ***
#
#
# *** No instances in image image_2457 to draw ***
#
#
# *** No instances in image image_2466 to draw ***
#
#
# *** No instances in image image_2478 to draw ***
#
#
# *** No instances in image image_2480 to draw ***
#
#
# *** No instances in image image_2488 to draw ***
#
#
# *** No instances in image image_2508 to draw ***
#
#
# *** No instances in image image_2510 to draw ***
#
#
# *** No instances in image image_2521 to draw ***
#
#
# *** No instances in image image_2552 to draw ***
#
#
# *** No instances in image image_2566 to draw ***
#
#
# *** No instances in image image_2572 to draw ***
#
#
# *** No instances in image image_2576 to draw ***
#
#
# *** No instances in image image_2589 to draw ***
#
#
# *** No instances in image image_2594 to draw ***
#
#
# *** No instances in image image_2602 to draw ***
#
#
# *** No instances in image image_2604 to draw ***
#
#
# *** No instances in image image_2608 to draw ***
#
#
# *** No instances in image image_2620 to draw ***
#
#
# *** No instances in image image_2621 to draw ***
#
#
# *** No instances in image image_2626 to draw ***
#
#
# *** No instances in image image_2641 to draw ***
#
#
# *** No instances in image image_2653 to draw ***
#
#
# *** No instances in image image_2664 to draw ***
#
#
# *** No instances in image image_2665 to draw ***
#
#
# *** No instances in image image_2671 to draw ***
#
#
# *** No instances in image image_2675 to draw ***
#
#
# *** No instances in image image_2686 to draw ***
#
#
# *** No instances in image image_2687 to draw ***
#
#
# *** No instances in image image_2745 to draw ***
#
#
# *** No instances in image image_2749 to draw ***
#
#
# *** No instances in image image_2757 to draw ***
#
#
# *** No instances in image image_2759 to draw ***
#
#
# *** No instances in image image_2768 to draw ***
#
#
# *** No instances in image image_2776 to draw ***
#
#
# *** No instances in image image_2779 to draw ***
#
#
# *** No instances in image image_2783 to draw ***
#
#
# *** No instances in image image_2801 to draw ***
# *** No instances in image image_2810 to draw ***
#
#
# *** No instances in image image_2812 to draw ***
#
#
# *** No instances in image image_2813 to draw ***
#
#
# *** No instances in image image_2825 to draw ***
#
#
# *** No instances in image image_2829 to draw ***
#
#
# *** No instances in image image_2838 to draw ***
#
#
# *** No instances in image image_2841 to draw ***
#
#
# *** No instances in image image_2842 to draw ***
#
#
# *** No instances in image image_2857 to draw ***
#
#
# *** No instances in image image_2861 to draw ***
#
#
# *** No instances in image image_2865 to draw ***
#
#
# *** No instances in image image_2866 to draw ***
#
#
# *** No instances in image image_2886 to draw ***
#
#
# *** No instances in image image_2890 to draw ***
#
#
# *** No instances in image image_2903 to draw ***
#
#
# *** No instances in image image_2904 to draw ***
#
#
# *** No instances in image image_2911 to draw ***
#
#
# *** No instances in image image_2914 to draw ***
#
#
# *** No instances in image image_2923 to draw ***
#
#
# *** No instances in image image_2924 to draw ***
#
#
# *** No instances in image image_2926 to draw ***
#
#
# *** No instances in image image_2942 to draw ***
#
#
# *** No instances in image image_2950 to draw ***
#
#
# *** No instances in image image_2951 to draw ***
#
#
# *** No instances in image image_2955 to draw ***
#
#
# *** No instances in image image_2968 to draw ***
#
#
# *** No instances in image image_2981 to draw ***
#
#
# *** No instances in image image_2990 to draw ***
#
#
# *** No instances in image image_2994 to draw ***
#
#
# *** No instances in image image_3000 to draw ***
#
#
# *** No instances in image image_3008 to draw ***
#
#
# *** No instances in image image_3017 to draw ***
#
#
# *** No instances in image image_3035 to draw ***
#
#
# *** No instances in image image_3044 to draw ***
#
#
# *** No instances in image image_3048 to draw ***
#
#
# *** No instances in image image_3050 to draw ***
#
#
# *** No instances in image image_3054 to draw ***
#
#
# *** No instances in image image_3064 to draw ***
#
#
# *** No instances in image image_3077 to draw ***
#
#
# *** No instances in image image_3079 to draw ***
#
#
# *** No instances in image image_3085 to draw ***
#
#
# *** No instances in image image_3095 to draw ***
#
#
# *** No instances in image image_3108 to draw ***
#
#
# *** No instances in image image_3111 to draw ***
#
#
# *** No instances in image image_3127 to draw ***
#
#
# *** No instances in image image_3135 to draw ***
#
#
# *** No instances in image image_3138 to draw ***
#
#
# *** No instances in image image_3148 to draw ***
#
#
# *** No instances in image image_3171 to draw ***
#
#
# *** No instances in image image_3198 to draw ***
#
#
# *** No instances in image image_3210 to draw ***
#
#
# *** No instances in image image_3214 to draw ***
#
#
# *** No instances in image image_3221 to draw ***
#
#
# *** No instances in image image_3224 to draw ***
#
#
# *** No instances in image image_3229 to draw ***
#
#
# *** No instances in image image_3230 to draw ***
#
#
# *** No instances in image image_3259 to draw ***
#
#
# *** No instances in image image_3262 to draw ***
#
#
# *** No instances in image image_3263 to draw ***
#
#
# *** No instances in image image_3267 to draw ***
#
#
# *** No instances in image image_3275 to draw ***
#
#
# *** No instances in image image_3285 to draw ***
#
#
# *** No instances in image image_3290 to draw ***
#
#
# *** No instances in image image_3293 to draw ***
#
#
# *** No instances in image image_3294 to draw ***
#
#
# *** No instances in image image_3304 to draw ***
#
#
# *** No instances in image image_3316 to draw ***
#
#
# *** No instances in image image_3346 to draw ***
#
#
# *** No instances in image image_3350 to draw ***
#
#
# *** No instances in image image_3355 to draw ***
#
#
# *** No instances in image image_3359 to draw ***
#
#
# *** No instances in image image_3361 to draw ***
#
#
# *** No instances in image image_3370 to draw ***
#
#
# *** No instances in image image_3381 to draw ***
#
#
# *** No instances in image image_3401 to draw ***
#
#
# *** No instances in image image_3411 to draw ***
#
#
# *** No instances in image image_3420 to draw ***
#
#
# *** No instances in image image_3433 to draw ***
#
#
# *** No instances in image image_3435 to draw ***
#
#
# *** No instances in image image_3437 to draw ***
#
#
# *** No instances in image image_3447 to draw ***
#
#
# *** No instances in image image_3455 to draw ***
#
#
# *** No instances in image image_3476 to draw ***
#
#
# *** No instances in image image_3485 to draw ***
#
#
# *** No instances in image image_3488 to draw ***
#
#
# *** No instances in image image_3489 to draw ***
#
#
# *** No instances in image image_3497 to draw ***
#
#
# *** No instances in image image_3500 to draw ***
#
#
# *** No instances in image image_3513 to draw ***
#
#
# *** No instances in image image_3524 to draw ***
#
#
# *** No instances in image image_3531 to draw ***
#
#
# *** No instances in image image_3540 to draw ***
#
#
# *** No instances in image image_3549 to draw ***
#
#
# *** No instances in image image_3560 to draw ***
#
#
# *** No instances in image image_3574 to draw ***
#
#
# *** No instances in image image_3575 to draw ***
#
#
# *** No instances in image image_3588 to draw ***
#
#
# *** No instances in image image_3592 to draw ***
#
#
# *** No instances in image image_3593 to draw ***
#
#
# *** No instances in image image_3603 to draw ***
#
#
# *** No instances in image image_3624 to draw ***
#
#
# *** No instances in image image_3631 to draw ***
#
#
# *** No instances in image image_3636 to draw ***
#
#
# *** No instances in image image_3663 to draw ***
#
#
# *** No instances in image image_3673 to draw ***
#
#
# *** No instances in image image_3674 to draw ***
#
#
# *** No instances in image image_3688 to draw ***

# %%
# !ffmpeg -framerate 30 -i output/image_%04d.jpg video_masked.mp4
# Out:
# ffmpeg version 3.4.4-0ubuntu0.18.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from 'output/*.jpg':
#   Duration: 00:54:40.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: mjpeg, yuvj420p(pc, bt470bg/unknown/unknown), 1280x720 [SAR 1:1 DAR 16:9], 1 fps, 1 tbr, 1 tbn, 1 tbc
# File 'video_masked.mp4' already exists. Overwrite ? [y/N] ^C
